# %%
from utils import *

# %% [markdown]
# ## Investigate how adding K virtual representations of N servers reduces URL allocation variance
#
# ### How to Use:
# - Call `convert_server_hash_to_assignments` with different values of K and N to generate pie plots of URL server allocation
# - The variance between the number of URLs assigned to each plot should generally decrease as K, N increase
#
# ### Some implementation notes, most things can be tweaked in `utils.py`
# - Its assumed that our hash function has 2^16 buckets.
# - Code is pretty un-optimized, stick with values of N < 10 and K < 500 for things to run and plot in reasonable time

# %%
# Usage: enter N servers with K virtual copies
visualize_server_url_assignments(N=10, K=1) 
visualize_server_url_assignments(N=10, K=50)
visualize_server_url_assignments(N=10, K=100)
